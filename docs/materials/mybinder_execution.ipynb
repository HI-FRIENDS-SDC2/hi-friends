# %% [markdown]
# # Execute HI-FRIENDS workflow
#
# [mybinder](https://mybinder.org/) is not the best platform to run large workflows, but it can be used to verify that the HI-FRIENDS workflow runs correctly.
#
# Execute the python command either in the notebook or in a terminal. After a few minutes the snakemake workflow will finish and in the cells below you will see some plots describing the workflow, and some diagnostic plots (note that `--check` runs the workflow on a tiny dummy data cube, so the results are not significant

# %%
from IPython.display import SVG, Image
import pandas as pd

# %%
# !python run.py --check
# Out:
# snakemake -j8 --use-conda --conda-frontend mamba --default-resources tmpdir=tmp  --resources bigfile=1 --config incube='interim/sofia_test_datacube.fits' sofia_param='config/dev12.par' subcube_id=[0] num_subcubes=16 pixel_overlap=0
# Building DAG of jobs...
# Nothing to be done.
# Complete log: /home/jovyan/.snakemake/log/2021-08-04T094706.359820.snakemake.log
# Now producing summary plots and report
# Building DAG of jobs...
# Creating report...
# Downloading resources and rendering HTML.
# Report created: summary/report.html.
# Building DAG of jobs...
# Building DAG of jobs...
# Building DAG of jobs...

# %% [markdown]
# # Plots describing the workflow that was just executed

# %%
SVG('summary/dag.svg')

# %%
SVG('summary/rulegraph.svg')

# %%
Image('results/plots/subcube_grid.png')

# %%
SVG('summary/filegraph.svg')

# %% [markdown]
# # Variables computed in the catalog
#
# The catalog for this data cube consists only of three sources. The filtered catalog ends up without any source (for the given parameters). This is just for illustrative purposes

# %%
df = pd.read_csv('results/catalogs/unfiltered_catalog.csv', delimiter=' ')
df
# Out:
#    id          ra        dec     hi_size  line_flux_integral  central_freq  \
# 0   0  180.967957  61.852244   43.716553           31.164553  1.414994e+09
# 1   1  181.042746  61.939711  129.474920          252.734697  1.415399e+09
# 2   2  181.070360  61.891065   95.684607           31.694303  1.414278e+09
#
#            pa          i         w20
# 0  238.689347  40.073057   58.276362
# 1  329.557973  59.627162  241.898752
# 2  304.652375  79.886453   18.850318

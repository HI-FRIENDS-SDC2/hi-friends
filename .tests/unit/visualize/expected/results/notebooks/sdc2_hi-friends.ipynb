# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/jmoldon/miniconda3/envs/snakemake/lib/python3.9/site-packages', '/mnt/scratch/sdc2/jmoldon/tests/unittest/hi-friends/workflow/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xaa\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c"results/catalogs/final_catalog.csv\x94\x8c)results/catalogs/catalog_w_duplicates.csv\x94\x8c"resources/sky_ldev_truthcat_v2.txt\x94\x8c results/plots/coord_subcubes.csv\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x13\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x19)}\x94\x8c\x05_name\x94h\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c,results/plots/output_params_distribution.png\x94\x8c\'results/notebooks/sdc2_hi-friends.ipynb\x94\x8c&results/plots/sky_detected_sources.png\x94e}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\xe8\x03M\xe8\x03\x8c\x03tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94uh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bh[K\x01h]K\x01h_M\xe8\x03haM\xe8\x03hchXub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94(\x8c$results/logs/visualize/visualize.log\x94\x8c\'results/notebooks/sdc2_hi-friends.ipynb\x94e}\x94(h\x0f}\x94\x8c\x08notebook\x94K\x01N\x86\x94sh\x11]\x94(h\x13h\x14eh\x13h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x13sNt\x94bh\x14h\x17h\x19\x85\x94R\x94(h\x19)}\x94h\x1dh\x14sNt\x94bhvhsub\x8c\x06config\x94}\x94(\x8c\x06incube\x94\x8c interim/sofia_test_datacube.fits\x94\x8c\x0bsofia_param\x94\x8c\x10config/dev12.par\x94\x8c\nsubcube_id\x94]\x94\x8c\x010\x94a\x8c\x0cnum_subcubes\x94K\x10\x8c\rpixel_overlap\x94K\x00\x8c\x07threads\x94K \x8c\ncoord_file\x94\x8c results/plots/coord_subcubes.csv\x94\x8c\tgrid_plot\x94\x8c\x1eresults/plots/subcube_grid.png\x94\x8c\x10scfind_threshold\x94G@\x10\x00\x00\x00\x00\x00\x00\x8c\x10reliability_fmin\x94G@\x18\x00\x00\x00\x00\x00\x00\x8c\x15reliability_threshold\x94G?\xd9\x99\x99\x99\x99\x99\x9au\x8c\x04rule\x94\x8c\tvisualize\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cF/mnt/scratch/sdc2/jmoldon/tests/unittest/hi-friends/workflow/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/scratch/sdc2/jmoldon/tests/unittest/hi-friends');
######## snakemake preamble end #########

# %%
import sys
import argparse
from spectral_cube import SpectralCube
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import glob

# %%
plt.rc('figure', facecolor='w')

def plot_subcubes(coord_subcubes, ax, ls='-', color=None, lw=1):
    for i, coord in  enumerate(coord_subcubes):
        xlo, ylo, xhi, yhi = coord
        ax.plot([xlo, xhi, xhi, xlo, xlo],
                 [ylo, ylo, yhi, yhi, ylo],
                 color=color, ls=ls, lw=lw)
        ax.annotate(f'{i}',
                     xy=(np.mean([xlo, xhi]),
                         np.mean([ylo, yhi]))
                     )
def plot_border(wcs, N):
    brc = wcs.pixel_to_world(0,0,0)[0]
    trc = wcs.pixel_to_world(0,N,0)[0]
    tlc = wcs.pixel_to_world(N,N,0)[0]
    blc = wcs.pixel_to_world(N,0,0)[0]
    plt.plot([brc.ra.deg, trc.ra.deg, tlc.ra.deg, blc.ra.deg, brc.ra.deg],
             [brc.dec.deg, trc.dec.deg, tlc.dec.deg, blc.dec.deg, brc.dec.deg],
            'k-', lw=4)

def plot_grid(coord_subcubes):
    ## Plot grid of subcubes
    #plt.subplot(projection=wcs, slices=['x','y', 0])  # It is not correcly projecting the pixels when using this mode. Alternatively, I could use APLpy
    plt.subplot()
    #plot_border(wcs, N)
    plot_subcubes(coord_subcubes)
    #plt.grid()
    plt.xlabel('R.A. [deg]')
    plt.ylabel('Dec. [deg]')
    plt.gca().invert_xaxis()
    #plt.savefig(grid_plot, bbox_inches='tight', dpi=200)

# %%
df = pd.read_csv('results/catalogs/final_catalog.csv', delimiter=' ')
df_truth = pd.read_csv('resources/sky_ldev_truthcat_v2.txt', delimiter=' ')

# %% [markdown]
# # Grid definition and detected sources

# %%
coord_subcubes = np.loadtxt('results/plots/coord_subcubes.csv', skiprows=1, delimiter=',')
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

plot_subcubes(coord_subcubes, ax=ax)
ax.invert_xaxis()
ax.set_xlabel('R.A. [deg]')
ax.set_ylabel('Dec. [deg]');

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

plot_subcubes(coord_subcubes, ax=ax)
#ax.plot(df_truth['ra'], df_truth['dec'], '+r')
ax.plot(df['ra'], df['dec'], '+k')
ax.invert_xaxis()

ax.set_xlabel('R.A. [deg]')
ax.set_ylabel('Dec. [deg]')

fig.savefig('results/plots/sky_detected_sources.png', bbox_inches='tight', dpi=150)

# %%
cat_files = sorted(glob.glob('results/sofia/*/subcube_*_final_catalog.csv'))
for cat_file in cat_files:
    with open(cat_file, 'r') as f:
        lines = f.readlines()
        print(cat_file, len(lines))
# Out:
# results/sofia/0/subcube_0_final_catalog.csv 4

# %% [markdown]
# # Distribution of output parameters

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 12))

for i, c in enumerate(['ra', 'dec', 'hi_size', 'line_flux_integral', 'central_freq', 'pa', 'i', 'w20']):
    ax = axs.flatten()[i]

    #sns.kdeplot(data=df_truth, x=c, color='r', lw=2, ax=ax)
    ax.set_title(c)
    if c in ['hi_size', 'line_flux_integral', 'w20']:
        ax.set_xscale('log')
        ax.set_yscale('log')
        sns.histplot(data=df, x=c, kde=False, log_scale=True, edgecolor='None', ax=ax)
        sns.histplot(data=df_truth, bins=20, x=c, kde=False, ax=ax, alpha=0.1, edgecolor='0.2', facecolor='0.8',  log_scale=True, element="step")
    else:
        sns.histplot(data=df, x=c, kde=False, edgecolor='None', ax=ax)
        sns.histplot(data=df_truth, bins=50, x=c, kde=False,  ax=ax, alpha=0.9, edgecolor='0.2', facecolor='0.8',  element="step")
        ax.set_yscale('log')

fig.savefig("results/plots/output_params_distribution.png", bbox_inches='tight', dpi=200)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

c = 'hi_size'
ax.set_xscale('log')
sns.histplot(data=df, x=c, edgecolor='None', kde=False, log_scale=True, ax=ax)
sns.histplot(data=df_truth, bins=20, x=c, kde=False, ax=ax, alpha=0.1, edgecolor='k', facecolor='0.8',  log_scale=True, element="step")
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

c = 'w20'
ax.set_xscale('log')
sns.histplot(data=df, x=c, edgecolor='None', kde=False, log_scale=True, ax=ax)
sns.histplot(data=df_truth, bins=20, x=c, kde=False, ax=ax, alpha=0.1, edgecolor='k', facecolor='0.8',  log_scale=True, element="step")
ax.set_yscale('log')

# %%
print(f"{np.mean(df['w20'])}+/-{np.std(df['w20'])}")
print(f"{np.mean(df_truth['w20'])}+/-{np.std(df_truth['w20'])}")
# Out:
# 106.34181041601259+/-97.19522109376112
# 252.10007959886386+/-123.8184368485116
